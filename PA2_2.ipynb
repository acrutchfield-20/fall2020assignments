# %%
import numpy as np
import pandas as pd
import altair as alt

# %%
fossil_data = pd.read_csv("input/fossil-fuel-co2-emissions-by-nation_filtered.csv")
fossil_data
# Out:
#        Year                    Country  Total  Solid Fuel  Liquid Fuel  \
# 0      1950                AFGHANISTAN     23           6           18
# 1      1950                    ALBANIA     81          12           68
# 2      1950                    ALGERIA   1033         514          475
# 3      1950                     ANGOLA     51          16           34
# 4      1950                  ARGENTINA   8168         972         6982
# ...     ...                        ...    ...         ...          ...
# 12457  2014                   VIET NAM  45517       19246        12694
# 12458  2014  WALLIS AND FUTUNA ISLANDS      6           0            6
# 12459  2014                      YEMEN   6190         137         5090
# 12460  2014                     ZAMBIA   1228         132          797
# 12461  2014                   ZIMBABWE   3278        2097         1005
#
#        Gas Fuel  Cement  Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# ...

# %%
#I had to create a copy of the original data file to delete all data but US data
#the original file is too large to perform time series on
us_data = pd.read_csv('input/fossil-fuel-co2-emissions-by-nation_filteredcopy.csv')
us_data
# Out:
#     Year                   Country    Total  Solid Fuel  Liquid Fuel  \
# 0   1950  UNITED STATES OF AMERICA   692124      343131       244760
# 1   1951  UNITED STATES OF AMERICA   712983      330676       262189
# 2   1952  UNITED STATES OF AMERICA   694618      293170       273190
# 3   1953  UNITED STATES OF AMERICA   711175      290927       286594
# 4   1954  UNITED STATES OF AMERICA   677689      249303       290178
# ..   ...                       ...      ...         ...          ...
# 60  2010  UNITED STATES OF AMERICA  1471375      521330       590751
# 61  2011  UNITED STATES OF AMERICA  1442509      498720       575746
# 62  2012  UNITED STATES OF AMERICA  1396083      443904       566582
# 63  2013  UNITED STATES OF AMERICA  1406916      450641       562260
# 64  2014  UNITED STATES OF AMERICA  1432855      450047       576531
#
#     Gas Fuel  Cement  Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# ...

# %%
#time series for US data
colors = ['red', 'blue', 'green','orange', 'purple', 'black','yellow', 'pink']
circle_size = 2
circle_opacity = 0.5
regression_opacity = 1
regression_method = "poly" 
width = 550
height = 220

#Field ID 3
base3 = alt.Chart(us_data).mark_circle(opacity=circle_opacity, color=colors[0], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
line3 = base3.mark_line(color=colors[0], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

#Field ID 4
base4 = alt.Chart(us_data).mark_circle(opacity=circle_opacity, color=colors[1], size=circle_size).encode(
    alt.X('Year:Q'),
   alt.Y('Solid Fuel:Q')
).properties(width=width, height=height)
line4 = base4.mark_line(color=colors[1], opacity=1,size=1).encode(x='Year:Q',y='Solid Fuel:Q')

#Field ID 5
base5 = alt.Chart(us_data).mark_circle(opacity=circle_opacity, color=colors[2], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Liquid Fuel:Q')
).properties(width=width, height=height)
line5 = base5.mark_line(color=colors[2], opacity=1,size=1).encode(x='Year:Q',y='Liquid Fuel:Q')

#Field ID 6
base6 = alt.Chart(us_data).mark_circle(opacity=circle_opacity, color=colors[3], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Gas Fuel:Q')
).properties(width=width, height=height)
line6 = base6.mark_line(color=colors[3], opacity=1,size=1).encode(x='Year:Q',y='Gas Fuel:Q')

#Field ID 7
base7 = alt.Chart(us_data).mark_circle(opacity=circle_opacity, color=colors[4], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Cement:Q')
).properties(width=width, height=height)
line7 = base7.mark_line(color=colors[4], opacity=1,size=1).encode(x='Year:Q',y='Cement:Q')

#Field ID 8
base8 = alt.Chart(us_data).mark_circle(opacity=circle_opacity, color=colors[5], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Gas Flaring:Q')
).properties(width=width, height=height)
line8 = base8.mark_line(color=colors[5], opacity=1,size=1).encode(x='Year:Q',y='Gas Flaring:Q')

#Field ID 9
base9 = alt.Chart(us_data).mark_circle(opacity=circle_opacity, color=colors[6], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line9 = base9.mark_line(color=colors[6], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q')

#Field ID 10
base10 = alt.Chart(us_data).mark_circle(opacity=circle_opacity, color=colors[7], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Bunker fuels (Not in Total):Q')
).properties(width=width, height=height)
line10 = base10.mark_line(color=colors[7], opacity=1,size=1).encode(x='Year:Q',y='Bunker fuels (Not in Total):Q')

alt.layer(base3,line3,base4,line4,base5,line5,base6,line6,base7,line7,base8,line8, base9,line9,base10,line10)
# Out:
# alt.LayerChart(...)

# %%
#10 country dataset
c10 = pd.read_csv('input/fossil-fuel-co2-emissions-by-nation_filteredcopy2.csv')
c10
# Out:
#      Year  Country  Total  Solid Fuel  Liquid Fuel  Gas Fuel  Cement  \
# 0    1953  ALGERIA   1092         422          599         0      70
# 1    1954  ALGERIA   1134         405          639         0      90
# 2    1955  ALGERIA   1258         435          731         0      92
# 3    1956  ALGERIA   1364         481          795         0      89
# 4    1957  ALGERIA   1512         539          876         0      97
# ..    ...      ...    ...         ...          ...       ...     ...
# 460  2010  BELARUS  17192         620         4620     11336     616
# 461  2011  BELARUS  17470         632         5479     10733     626
# 462  2012  BELARUS  17241         803         5193     10579     667
# 463  2013  BELARUS  17390         858         5170     10675     688
# 464  2014  BELARUS  17316         888         5072     10592     764
#
#      Gas Flaring  Per Capita  Bunker fuels (Not in Total)
# 0              0        0.12                          620
# ...

# %%
##time series for 10 countries
Algeria = 'blue'
Andorra = 'yellow'
Angola = 'blue'
Armenia = 'black'
Aruba = 'red'
Australia = 'purple'
Bahamas = 'pink'
Bangladesh = 'brown'
Barbados = 'orange'
Belarus = 'silver'

colors = [Algeria, Andorra, Angola, Armenia, Aruba, Australia, Bahamas, Bangladesh, Barbados, Belarus]
circle_size = 2
circle_opacity = 0.5
regression_opacity = 1
regression_method = "poly" 
width = 550
height = 250

#Field ID 3 and 9 Algeria
alg3 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[0], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
algline = alg3.mark_line(color=colors[0], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

alg9 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[0], size=circle_size).encode(
    alt.X('Year:Q'),
   alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line_alg = alg9.mark_line(color=colors[0], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q')

#Field ID 3 and 9 Andorra 
and3 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[1], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
andline = and3.mark_line(color=colors[1], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

and9 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[1], size=circle_size).encode(
    alt.X('Year:Q'),
   alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line_and = and9.mark_line(color=colors[1], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q')

#Field ID 3 and 9 Angola
ang3 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[2], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
angline = and3.mark_line(color=colors[2], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

ang9 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[2], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line_ang = ang9.mark_line(color=colors[2], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q')


#Field ID 3 and 9 Armenia
arm3 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[3], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
armline = arm3.mark_line(color=colors[3], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

arm9 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[3], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line_arm = arm9.mark_line(color=colors[3], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q')


#Field ID 3 and 9 Aruba 
ar3 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[4], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
arline = ar3.mark_line(color=colors[4], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

ar9 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[4], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line_ar = ar9.mark_line(color=colors[4], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q')


#Field ID 3 and 9 Australia
au3 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[5], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
auline = au3.mark_line(color=colors[5], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

au9 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[5], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line_au = au9.mark_line(color=colors[5], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q') 

#Field ID 3 and 9 Bahamas 
ba3 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[6], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
baline = ba3.mark_line(color=colors[6], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

ba9 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[6], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line_ba = ba9.mark_line(color=colors[6], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q') 

#Field ID 3 and 9 Bangladesh 
ban3 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[7], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
banline = ba3.mark_line(color=colors[7], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

ban9 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[7], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line_ban = ban9.mark_line(color=colors[7], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q') 

#Field ID 3 and 9 Barbados
bar3 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[8], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
barline = bar3.mark_line(color=colors[8], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

bar9 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[8], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line_bar = bar9.mark_line(color=colors[8], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q') 


#Field ID 3 and 9 Belarus 
bel3 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[9], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Total:Q')
).properties(width=width, height=height)
belline = bel3.mark_line(color=colors[9], opacity=1,size=1).encode(x='Year:Q',y='Total:Q')

bel9 = alt.Chart(c10).mark_circle(opacity=circle_opacity, color=colors[9], size=circle_size).encode(
    alt.X('Year:Q'),
    alt.Y('Per Capita:Q')
).properties(width=width, height=height)
line_bel = bar9.mark_line(color=colors[9], opacity=1,size=1).encode(x='Year:Q',y='Per Capita:Q') 



alt.layer(alg3,algline,alg9,line_alg, and3, andline, and9, line_and, ang3, angline, ang9, line_ang, arm3,armline,arm9,line_arm,ar3,arline,ar9,line_ar,au3,auline,au9,line_au,ba3,baline,ba9,line_ba,ban3,banline,ban9,line_ban, bar3,barline,bar9,line_bar)
# Out:
# alt.LayerChart(...)

# %%
#US visualizations

#scatter with trend showing correlation between liquid fuel and solid fuel
scplot = alt.Chart(us_data).mark_point().encode(
    x=alt.X('Liquid Fuel', scale=alt.Scale(domain=(0, 700000))),
    y=alt.Y('Solid Fuel',scale=alt.Scale(domain=(0, 700000)))
)
scplot 
scplot+scplot.transform_regression('Liquid Fuel', 'Solid Fuel',method="linear"
).mark_line(color="red")
# Out:
# alt.LayerChart(...)

# %%
#bar graph comparing Bunker fuels (Not in Total) and per capita, categorized by year
alt.Chart(us_data).mark_bar().encode(
    x = 'Per Capita:Q',
    y="Bunker fuels (Not in Total):Q", 
    color = 'Year:N'
)
# Out:
# alt.Chart(...)

# %%
# 4. horizontal stacked bar chart for sum of Total vs Per Capita, grouped by year
alt.Chart(us_data).mark_bar().encode(
    x='sum(Total)',
    y='Per Capita',
    color='Year'
)
# Out:
# alt.Chart(...)
