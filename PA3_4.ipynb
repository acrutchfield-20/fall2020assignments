# %%
import numpy as np
import pandas as pd
import altair as alt

# %%
pip install scipy
# Out:
# ...
# WARNING: You are using pip version 20.1.1; however, version 20.2.4 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import scipy
from scipy import stats

# %%
input4 = pd.read_csv("input/input_4.csv")
input4
# Out:
#       ami  No Treatment
# 0   21.39          56.7
# 1   20.50          65.5
# 2   19.24          52.7
# 3   20.27          47.5
# 4   18.54          65.0
# 5   21.50          50.9
# 6   19.03          53.9
# 7   20.03          49.7
# 8   22.21          52.2
# 9   17.39          63.0
# 10  18.09          64.9
# 11  17.58          65.8
# 12  24.46          53.5
# 13  18.06          55.8
# 14  22.51          55.9
# 15  19.89          49.8
# 16  19.59          51.1
# 17  22.14          50.9
# 18  20.63          62.0
# 19  20.82          49.9
# 20  16.96          59.1
# 21  21.22          49.5
# 22  19.07          53.8
# 23  19.32          52.6
# 24  19.49          57.7
# 25  21.44          55.3
# 26  18.08          53.0
# 27  20.67          60.3
# 28  20.56          51.9
# 29  16.14          60.0
# 30  19.10          56.6
# 31  18.25          60.3
# 32  18.77          56.5
# 33  19.13          54.5
# 34  21.40          50.7
# 35  20.43          58.9
# 36  22.45          59.3
# ...

# %%
ami_list = input4['ami'].to_list()
print('AMI:', ami_list)
nt_list = input4['No Treatment'].to_list()
print('No Treatment: ', nt_list)
# Out:
# AMI: [21.39, 20.5, 19.24, 20.27, 18.54, 21.5, 19.03, 20.03, 22.21, 17.39, 18.09, 17.58, 24.46, 18.06, 22.51, 19.89, 19.59, 22.14, 20.63, 20.82, 16.96, 21.22, 19.07, 19.32, 19.49, 21.44, 18.08, 20.67, 20.56, 16.14, 19.1, 18.25, 18.77, 19.13, 21.4, 20.43, 22.45, 18.23, 21.32, 18.31, 17.49, 18.26, 16.21, 25.25, 20.65, 17.38, 22.23, 23.8, 19.26, 20.34]
# No Treatment:  [56.7, 65.5, 52.7, 47.5, 65.0, 50.9, 53.9, 49.7, 52.2, 63.0, 64.9, 65.8, 53.5, 55.8, 55.9, 49.8, 51.1, 50.9, 62.0, 49.9, 59.1, 49.5, 53.8, 52.6, 57.7, 55.3, 53.0, 60.3, 51.9, 60.0, 56.6, 60.3, 56.5, 54.5, 50.7, 58.9, 59.3, 53.0, 49.0, 51.4, 54.8, 51.7, 59.6, 51.2, 42.8, 54.5, 53.5, 52.2, 49.2, 64.8]

# %%
x = np.concatenate((ami_list, nt_list))
k2, p = stats.normaltest(x)
alpha = 1e-3
print("p = {:g}".format(p))
if p < alpha:  # null hypothesis: x comes from a normal distribution
    print("The null hypothesis can be rejected")
else:
    print("The null hypothesis cannot be rejected")
# Out:
# p = 2.15831e-240
# The null hypothesis can be rejected

# %%
#alt.Chart(input4).mark_bar().encode(
 #   x='AMI',
  #  y='No Treatment'
#)

# %%
#pearsons correlation test
stats.pearsonr(ami_list,nt_list)
# Out:
# (-0.33983510499430475, 0.014693770236620178)

# %%
df = 49 - 2 #unsure as to why the notebook is taking 49 entries from my spreadsheet vs. 51
df
# Out:
# 47

# %%
#alt.Chart(input4).mark_point().encode(
 #   x='AMI',
  #  y='No Treatment',
    #size='Acceleration'
#)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/altair/vegalite/v4/api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ...
